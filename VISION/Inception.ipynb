# %% [markdown]
# # Inception

# %%
import keras
from keras.layers import Layer
import keras.backend as K
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Input, concatenate, GlobalAveragePooling2D, AveragePooling2D, Flatten

import cv2 
import numpy as np 
from keras.datasets import cifar10 
from keras import backend as K 
from keras.utils import np_utils

import math 
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler

# %% [markdown]
# ### Load Data

# %%
num_classes = 10

# 데이터 가져오는 함수
def load_cifar10_data(img_rows, img_cols):
    # CIFAR10 train, valid 데이터 로드
    (X_train, Y_train), (X_valid, Y_valid) = cifar10.load_data()
    
    # 데이터 크기 일단 축소
    X_train = X_train[0:3000,:,:,:]
    X_valid = X_valid[0:600,:,:,:]
    Y_train = Y_train[0:3000,:]
    Y_valid = Y_valid[0:600,:]
    
    # GoogleNet의 image input layer인 224x224x3로, cv2.resize 하기
    X_train = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_train[:,:,:,:]])
    X_valid = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_valid[:,:,:,:]])

    # 전처리
    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_valid = np_utils.to_categorical(Y_valid, num_classes)
    
    X_train = X_train / 255.0
    X_valid = X_valid / 255.0

    return X_train, Y_train, X_valid, Y_valid

# %%
X_train, y_train, X_test, y_test = load_cifar10_data(224, 224)

# %%
X_train.shape
# Out:
# (3000, 224, 224, 3)

# %% [markdown]
# ### Inception Module

# %%
def inception_module(x,filters_1x1,filters_3x3_reduce,filters_3x3,
                     filters_5x5_reduce,filters_5x5,filters_pool_proj,name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu',
                      kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu',
                      kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu',
                      kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu',
                      kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu',
                      kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu',
                       kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %%
kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
input_layer = Input(shape=(224, 224, 3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(input_layer)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


x1 = AveragePooling2D((5, 5), strides=3)(x)
x1 = Conv2D(128, (1, 1), padding='same', activation='relu')(x1)
x1 = Flatten()(x1)
x1 = Dense(1024, activation='relu')(x1)
x1 = Dropout(0.7)(x1)
x1 = Dense(10, activation='softmax', name='auxilliary_output_1')(x1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


x2 = AveragePooling2D((5, 5), strides=3)(x)
x2 = Conv2D(128, (1, 1), padding='same', activation='relu')(x2)
x2 = Flatten()(x2)
x2 = Dense(1024, activation='relu')(x2)
x2 = Dropout(0.7)(x2)
x2 = Dense(10, activation='softmax', name='auxilliary_output_2')(x2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

x = Dense(10, activation='softmax', name='output')(x)
model = Model(input_layer, [x, x1, x2], name='inception_v1')

model.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 56, 56, 64)   4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 192)  221376      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_12[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_19[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_25[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_31[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_38[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_44[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_50[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           10250       dropout_2[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_1 (Dense)     (None, 10)           10250       dropout[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_2 (Dense)     (None, 10)           10250       dropout_1[0][0]
# ==================================================================================================
# Total params: 10,334,030
# Trainable params: 10,334,030
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 학습

# %%
epochs = 25
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])

# %%
history = model.fit(X_train, [y_train, y_train, y_train], validation_data=(X_test, [y_test, y_test, y_test]), epochs=epochs, batch_size=256, callbacks=[lr_sc])
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 1/25
#  2/12 [====>.........................] - ETA: 3s - loss: 4.0761 - output_loss: 2.5090 - auxilliary_output_1_loss: 2.5652 - auxilliary_output_2_loss: 2.6582 - output_accuracy: 0.1074 - auxilliary_output_1_accuracy: 0.0684 - auxilliary_output_2_accuracy: 0.0918WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2682s vs `on_train_batch_end` time: 0.5170s). Check your callbacks.
# 12/12 [==============================] - 15s 1s/step - loss: 3.9107 - output_loss: 2.4578 - auxilliary_output_1_loss: 2.4131 - auxilliary_output_2_loss: 2.4297 - output_accuracy: 0.1007 - auxilliary_output_1_accuracy: 0.0873 - auxilliary_output_2_accuracy: 0.0940 - val_loss: 3.7058 - val_output_loss: 2.3225 - val_auxilliary_output_1_loss: 2.3089 - val_auxilliary_output_2_loss: 2.3023 - val_output_accuracy: 0.1167 - val_auxilliary_output_1_accuracy: 0.0950 - val_auxilliary_output_2_accuracy: 0.1167
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 2/25
# 12/12 [==============================] - 10s 807ms/step - loss: 3.7618 - output_loss: 2.3728 - auxilliary_output_1_loss: 2.3172 - auxilliary_output_2_loss: 2.3127 - output_accuracy: 0.0997 - auxilliary_output_1_accuracy: 0.0967 - auxilliary_output_2_accuracy: 0.1033 - val_loss: 3.6897 - val_output_loss: 2.3084 - val_auxilliary_output_1_loss: 2.3018 - val_auxilliary_output_2_loss: 2.3026 - val_output_accuracy: 0.1183 - val_auxilliary_output_1_accuracy: 0.1333 - val_auxilliary_output_2_accuracy: 0.0850
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 3/25
# 12/12 [==============================] - 10s 820ms/step - loss: 3.7350 - output_loss: 2.3517 - auxilliary_output_1_loss: 2.3036 - auxilliary_output_2_loss: 2.3074 - output_accuracy: 0.0913 - auxilliary_output_1_accuracy: 0.1043 - auxilliary_output_2_accuracy: 0.1010 - val_loss: 3.6927 - val_output_loss: 2.3132 - val_auxilliary_output_1_loss: 2.2983 - val_auxilliary_output_2_loss: 2.3001 - val_output_accuracy: 0.1350 - val_auxilliary_output_1_accuracy: 0.0967 - val_auxilliary_output_2_accuracy: 0.0967
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 4/25
# 12/12 [==============================] - 10s 847ms/step - loss: 3.7229 - output_loss: 2.3417 - auxilliary_output_1_loss: 2.3000 - auxilliary_output_2_loss: 2.3040 - output_accuracy: 0.1080 - auxilliary_output_1_accuracy: 0.1163 - auxilliary_output_2_accuracy: 0.1070 - val_loss: 3.7156 - val_output_loss: 2.3362 - val_auxilliary_output_1_loss: 2.2980 - val_auxilliary_output_2_loss: 2.3002 - val_output_accuracy: 0.0767 - val_auxilliary_output_1_accuracy: 0.0967 - val_auxilliary_output_2_accuracy: 0.1250
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 5/25
# 12/12 [==============================] - 10s 865ms/step - loss: 3.7153 - output_loss: 2.3338 - auxilliary_output_1_loss: 2.2996 - auxilliary_output_2_loss: 2.3052 - output_accuracy: 0.0910 - auxilliary_output_1_accuracy: 0.1107 - auxilliary_output_2_accuracy: 0.1023 - val_loss: 3.6858 - val_output_loss: 2.3084 - val_auxilliary_output_1_loss: 2.2905 - val_auxilliary_output_2_loss: 2.3007 - val_output_accuracy: 0.0967 - val_auxilliary_output_1_accuracy: 0.1333 - val_auxilliary_output_2_accuracy: 0.0967
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 6/25
# 12/12 [==============================] - 10s 870ms/step - loss: 3.6945 - output_loss: 2.3176 - auxilliary_output_1_loss: 2.2901 - auxilliary_output_2_loss: 2.2995 - output_accuracy: 0.1060 - auxilliary_output_1_accuracy: 0.1273 - auxilliary_output_2_accuracy: 0.1180 - val_loss: 3.6659 - val_output_loss: 2.2930 - val_auxilliary_output_1_loss: 2.2781 - val_auxilliary_output_2_loss: 2.2982 - val_output_accuracy: 0.1983 - val_auxilliary_output_1_accuracy: 0.2083 - val_auxilliary_output_2_accuracy: 0.1533
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 7/25
# 12/12 [==============================] - 10s 846ms/step - loss: 3.6840 - output_loss: 2.3132 - auxilliary_output_1_loss: 2.2738 - auxilliary_output_2_loss: 2.2956 - output_accuracy: 0.1113 - auxilliary_output_1_accuracy: 0.1437 - auxilliary_output_2_accuracy: 0.1263 - val_loss: 3.6418 - val_output_loss: 2.2809 - val_auxilliary_output_1_loss: 2.2488 - val_auxilliary_output_2_loss: 2.2877 - val_output_accuracy: 0.1300 - val_auxilliary_output_1_accuracy: 0.2283 - val_auxilliary_output_2_accuracy: 0.1750
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 8/25
# 12/12 [==============================] - 10s 834ms/step - loss: 3.6327 - output_loss: 2.2745 - auxilliary_output_1_loss: 2.2460 - auxilliary_output_2_loss: 2.2812 - output_accuracy: 0.1390 - auxilliary_output_1_accuracy: 0.1583 - auxilliary_output_2_accuracy: 0.1480 - val_loss: 3.5653 - val_output_loss: 2.2307 - val_auxilliary_output_1_loss: 2.1884 - val_auxilliary_output_2_loss: 2.2603 - val_output_accuracy: 0.1367 - val_auxilliary_output_1_accuracy: 0.2550 - val_auxilliary_output_2_accuracy: 0.1750
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 9/25
# 12/12 [==============================] - 10s 832ms/step - loss: 3.5731 - output_loss: 2.2327 - auxilliary_output_1_loss: 2.2100 - auxilliary_output_2_loss: 2.2581 - output_accuracy: 0.1623 - auxilliary_output_1_accuracy: 0.1743 - auxilliary_output_2_accuracy: 0.1553 - val_loss: 3.5416 - val_output_loss: 2.2351 - val_auxilliary_output_1_loss: 2.1514 - val_auxilliary_output_2_loss: 2.2036 - val_output_accuracy: 0.1817 - val_auxilliary_output_1_accuracy: 0.2233 - val_auxilliary_output_2_accuracy: 0.1983
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 10/25
# 12/12 [==============================] - 10s 827ms/step - loss: 3.4685 - output_loss: 2.1653 - auxilliary_output_1_loss: 2.1564 - auxilliary_output_2_loss: 2.1876 - output_accuracy: 0.1883 - auxilliary_output_1_accuracy: 0.1877 - auxilliary_output_2_accuracy: 0.1707 - val_loss: 3.3316 - val_output_loss: 2.0909 - val_auxilliary_output_1_loss: 2.0544 - val_auxilliary_output_2_loss: 2.0815 - val_output_accuracy: 0.2067 - val_auxilliary_output_1_accuracy: 0.2667 - val_auxilliary_output_2_accuracy: 0.2617
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 11/25
# 12/12 [==============================] - 10s 837ms/step - loss: 3.3929 - output_loss: 2.1185 - auxilliary_output_1_loss: 2.1124 - auxilliary_output_2_loss: 2.1356 - output_accuracy: 0.1880 - auxilliary_output_1_accuracy: 0.1993 - auxilliary_output_2_accuracy: 0.1963 - val_loss: 3.2897 - val_output_loss: 2.0652 - val_auxilliary_output_1_loss: 2.0319 - val_auxilliary_output_2_loss: 2.0499 - val_output_accuracy: 0.2700 - val_auxilliary_output_1_accuracy: 0.2617 - val_auxilliary_output_2_accuracy: 0.2533
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 12/25
# 12/12 [==============================] - 10s 843ms/step - loss: 3.3750 - output_loss: 2.1126 - auxilliary_output_1_loss: 2.0962 - auxilliary_output_2_loss: 2.1118 - output_accuracy: 0.2043 - auxilliary_output_1_accuracy: 0.2147 - auxilliary_output_2_accuracy: 0.2087 - val_loss: 3.2975 - val_output_loss: 2.0847 - val_auxilliary_output_1_loss: 2.0106 - val_auxilliary_output_2_loss: 2.0324 - val_output_accuracy: 0.1783 - val_auxilliary_output_1_accuracy: 0.2833 - val_auxilliary_output_2_accuracy: 0.3017
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 13/25
# 12/12 [==============================] - 10s 844ms/step - loss: 3.3527 - output_loss: 2.0994 - auxilliary_output_1_loss: 2.0797 - auxilliary_output_2_loss: 2.0980 - output_accuracy: 0.2060 - auxilliary_output_1_accuracy: 0.2157 - auxilliary_output_2_accuracy: 0.2047 - val_loss: 3.2184 - val_output_loss: 2.0233 - val_auxilliary_output_1_loss: 1.9842 - val_auxilliary_output_2_loss: 1.9994 - val_output_accuracy: 0.2533 - val_auxilliary_output_1_accuracy: 0.2983 - val_auxilliary_output_2_accuracy: 0.2967
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 14/25
# 12/12 [==============================] - 10s 841ms/step - loss: 3.3056 - output_loss: 2.0716 - auxilliary_output_1_loss: 2.0437 - auxilliary_output_2_loss: 2.0694 - output_accuracy: 0.2093 - auxilliary_output_1_accuracy: 0.2340 - auxilliary_output_2_accuracy: 0.2143 - val_loss: 3.2830 - val_output_loss: 2.0769 - val_auxilliary_output_1_loss: 1.9976 - val_auxilliary_output_2_loss: 2.0228 - val_output_accuracy: 0.2583 - val_auxilliary_output_1_accuracy: 0.2800 - val_auxilliary_output_2_accuracy: 0.2617
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0096.
# Epoch 15/25
# 12/12 [==============================] - 10s 836ms/step - loss: 3.3108 - output_loss: 2.0841 - auxilliary_output_1_loss: 2.0370 - auxilliary_output_2_loss: 2.0521 - output_accuracy: 0.2023 - auxilliary_output_1_accuracy: 0.2373 - auxilliary_output_2_accuracy: 0.2260 - val_loss: 3.2120 - val_output_loss: 2.0326 - val_auxilliary_output_1_loss: 1.9526 - val_auxilliary_output_2_loss: 1.9786 - val_output_accuracy: 0.2583 - val_auxilliary_output_1_accuracy: 0.3050 - val_auxilliary_output_2_accuracy: 0.2983
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 16/25
# 12/12 [==============================] - 10s 832ms/step - loss: 3.2440 - output_loss: 2.0302 - auxilliary_output_1_loss: 2.0136 - auxilliary_output_2_loss: 2.0325 - output_accuracy: 0.2433 - auxilliary_output_1_accuracy: 0.2670 - auxilliary_output_2_accuracy: 0.2387 - val_loss: 3.1503 - val_output_loss: 1.9860 - val_auxilliary_output_1_loss: 1.9302 - val_auxilliary_output_2_loss: 1.9506 - val_output_accuracy: 0.2783 - val_auxilliary_output_1_accuracy: 0.3033 - val_auxilliary_output_2_accuracy: 0.3117
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 17/25
# 12/12 [==============================] - 10s 836ms/step - loss: 3.2286 - output_loss: 2.0282 - auxilliary_output_1_loss: 1.9971 - auxilliary_output_2_loss: 2.0044 - output_accuracy: 0.2313 - auxilliary_output_1_accuracy: 0.2430 - auxilliary_output_2_accuracy: 0.2477 - val_loss: 3.1117 - val_output_loss: 1.9618 - val_auxilliary_output_1_loss: 1.9123 - val_auxilliary_output_2_loss: 1.9208 - val_output_accuracy: 0.2800 - val_auxilliary_output_1_accuracy: 0.3017 - val_auxilliary_output_2_accuracy: 0.3033
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 18/25
# 12/12 [==============================] - 10s 837ms/step - loss: 3.2509 - output_loss: 2.0455 - auxilliary_output_1_loss: 2.0005 - auxilliary_output_2_loss: 2.0174 - output_accuracy: 0.2303 - auxilliary_output_1_accuracy: 0.2680 - auxilliary_output_2_accuracy: 0.2480 - val_loss: 3.1549 - val_output_loss: 1.9920 - val_auxilliary_output_1_loss: 1.9318 - val_auxilliary_output_2_loss: 1.9446 - val_output_accuracy: 0.2167 - val_auxilliary_output_1_accuracy: 0.2950 - val_auxilliary_output_2_accuracy: 0.2883
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 19/25
# 12/12 [==============================] - 10s 838ms/step - loss: 3.2214 - output_loss: 2.0231 - auxilliary_output_1_loss: 1.9817 - auxilliary_output_2_loss: 2.0128 - output_accuracy: 0.2303 - auxilliary_output_1_accuracy: 0.2690 - auxilliary_output_2_accuracy: 0.2487 - val_loss: 3.1582 - val_output_loss: 2.0057 - val_auxilliary_output_1_loss: 1.9117 - val_auxilliary_output_2_loss: 1.9299 - val_output_accuracy: 0.2417 - val_auxilliary_output_1_accuracy: 0.3167 - val_auxilliary_output_2_accuracy: 0.3150
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 20/25
# 12/12 [==============================] - 10s 843ms/step - loss: 3.3052 - output_loss: 2.0823 - auxilliary_output_1_loss: 2.0315 - auxilliary_output_2_loss: 2.0449 - output_accuracy: 0.2063 - auxilliary_output_1_accuracy: 0.2340 - auxilliary_output_2_accuracy: 0.2323 - val_loss: 3.2421 - val_output_loss: 2.0571 - val_auxilliary_output_1_loss: 1.9488 - val_auxilliary_output_2_loss: 2.0012 - val_output_accuracy: 0.2433 - val_auxilliary_output_1_accuracy: 0.3033 - val_auxilliary_output_2_accuracy: 0.2767
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 21/25
# 12/12 [==============================] - 10s 842ms/step - loss: 3.2398 - output_loss: 2.0420 - auxilliary_output_1_loss: 1.9806 - auxilliary_output_2_loss: 2.0121 - output_accuracy: 0.2340 - auxilliary_output_1_accuracy: 0.2707 - auxilliary_output_2_accuracy: 0.2577 - val_loss: 3.1015 - val_output_loss: 1.9575 - val_auxilliary_output_1_loss: 1.8964 - val_auxilliary_output_2_loss: 1.9168 - val_output_accuracy: 0.2983 - val_auxilliary_output_1_accuracy: 0.3250 - val_auxilliary_output_2_accuracy: 0.3183
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 22/25
# 12/12 [==============================] - 10s 839ms/step - loss: 3.1618 - output_loss: 1.9808 - auxilliary_output_1_loss: 1.9564 - auxilliary_output_2_loss: 1.9802 - output_accuracy: 0.2513 - auxilliary_output_1_accuracy: 0.2693 - auxilliary_output_2_accuracy: 0.2583 - val_loss: 3.0780 - val_output_loss: 1.9426 - val_auxilliary_output_1_loss: 1.8809 - val_auxilliary_output_2_loss: 1.9036 - val_output_accuracy: 0.2467 - val_auxilliary_output_1_accuracy: 0.3283 - val_auxilliary_output_2_accuracy: 0.3133
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009216.
# Epoch 23/25
# 12/12 [==============================] - 10s 842ms/step - loss: 3.1134 - output_loss: 1.9521 - auxilliary_output_1_loss: 1.9283 - auxilliary_output_2_loss: 1.9426 - output_accuracy: 0.2577 - auxilliary_output_1_accuracy: 0.2787 - auxilliary_output_2_accuracy: 0.2880 - val_loss: 3.0072 - val_output_loss: 1.8905 - val_auxilliary_output_1_loss: 1.8565 - val_auxilliary_output_2_loss: 1.8658 - val_output_accuracy: 0.3167 - val_auxilliary_output_1_accuracy: 0.3250 - val_auxilliary_output_2_accuracy: 0.3267
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.008847359999999999.
# Epoch 24/25
# 12/12 [==============================] - 10s 838ms/step - loss: 3.0880 - output_loss: 1.9316 - auxilliary_output_1_loss: 1.9235 - auxilliary_output_2_loss: 1.9312 - output_accuracy: 0.2733 - auxilliary_output_1_accuracy: 0.2743 - auxilliary_output_2_accuracy: 0.2877 - val_loss: 3.0652 - val_output_loss: 1.9262 - val_auxilliary_output_1_loss: 1.8922 - val_auxilliary_output_2_loss: 1.9045 - val_output_accuracy: 0.3100 - val_auxilliary_output_1_accuracy: 0.3367 - val_auxilliary_output_2_accuracy: 0.3150
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.008847359999999999.
# Epoch 25/25
# 12/12 [==============================] - 10s 834ms/step - loss: 3.0849 - output_loss: 1.9342 - auxilliary_output_1_loss: 1.9200 - auxilliary_output_2_loss: 1.9156 - output_accuracy: 0.2643 - auxilliary_output_1_accuracy: 0.2950 - auxilliary_output_2_accuracy: 0.2917 - val_loss: 3.0228 - val_output_loss: 1.9009 - val_auxilliary_output_1_loss: 1.8680 - val_auxilliary_output_2_loss: 1.8715 - val_output_accuracy: 0.2583 - val_auxilliary_output_1_accuracy: 0.3133 - val_auxilliary_output_2_accuracy: 0.2983
